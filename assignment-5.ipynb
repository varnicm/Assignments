# %%
pwd
# Out:
# '/Users/moesanjari/Desktop/Fall 2023/Data Science/week-5'

# %%
import pandas as pd

df = pd.read_csv('../../../sample_dataset1.txt', header=None)
df.columns=['Item1','Item2','Item3','Item4','class']

df.head()
# Out:
#    Item1  Item2  Item3  Item4    class
# 0    5.4    3.7    1.5    0.2  Class-A
# 1    4.8    3.4    1.6    0.2  Class-A
# 2    4.8    3.0    1.4    0.1  Class-A
# 3    4.3    3.0    1.1    0.1  Class-A
# 4    5.8    4.0    1.2    0.2  Class-A

# %%
from pandas.api.types import is_numeric_dtype
summary = df.describe()
for col in df.columns:
    if is_numeric_dtype(df[col]):
        print("%s:"% (col))
        print("\t Average : %.2f" % df[col].mean())
        print("\t Standard Deviation : %.2f" % df[col].std())
        print("\t Minimum : %.2f" % df[col].min())
        print("\t Maximum : %.2f" % df[col].max())
# Out:
# Item1:
# 	 Average : 5.86
# 	 Standard Deviation : 0.82
# 	 Minimum : 4.30
# 	 Maximum : 7.90
# Item2:
# 	 Average : 3.07
# 	 Standard Deviation : 0.44
# 	 Minimum : 2.00
# 	 Maximum : 4.40
# Item3:
# 	 Average : 3.76
# 	 Standard Deviation : 1.76
# 	 Minimum : 1.00
# 	 Maximum : 6.70
# Item4:
# 	 Average : 1.21
# 	 Standard Deviation : 0.76
# 	 Minimum : 0.10
# 	 Maximum : 2.50

# %%
df['class'].value_counts()
# Out:
# class
# Class-A    40
# Class-B    40
# Class-C    40
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             Item1       Item2       Item3       Item4
# count  120.000000  120.000000  120.000000  120.000000
# mean     5.861667    3.066667    3.760000    1.205833
# std      0.819939    0.441223    1.758838    0.762602
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.425000    3.325000    5.100000    1.800000
# max      7.900000    4.400000    6.700000    2.500000

# %%
pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/af/f3/fb27b3b902fc759bbca3f9d0336c48069c3022e57552c4b0095d997c7ea8/matplotlib-3.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/2c/8e/656f8e7cd316aa68d9824744773e90dbd71f847429d10c82001e927480a2/contourpy-1.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/1f/80/c5ce42faa7dec3c22fe587e56e141c7416c19a13a96bd4972bf1b55cb494/fonttools-4.42.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.0/151.0 kB 2.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %matplotlib inline

df['Item1'].hist(bins=8)
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

csv_data = pd.read_csv('../../../sample_dataset2.csv', header='infer')

csv_data.index=pd.to_datetime(csv_data['DATE'])
csv_data=csv_data['PRCP']

ax=csv_data.plot(kind='line',figsize=(15,3))
ax.set_title('Daily Precipitation (variance= %.4f)' % (csv_data.var()))
# Out:
# Text(0.5, 1.0, 'Daily Precipitation (variance= 0.0515)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

daily = pd.read_csv('../../../sample_dataset2.csv', header='infer')
daily.index = pd.to_datetime(daily['DATE'])

daily = daily['PRCP']

monthly_data = daily.groupby(pd.Grouper(freq='M')).sum()
ax = monthly_data.plot(kind='line', figsize=(15, 3))
ax.set_title('Monthly Precipitation (variance= %.4f)' % (monthly_data.var()))
# Out:
# Text(0.5, 1.0, 'Monthly Precipitation (variance= 2.2656)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

csv_data = pd.read_csv('../../../sample_dataset2.csv', header='infer')
csv_data.index = pd.to_datetime(csv_data['DATE'])
csv_data = csv_data['PRCP']
monthly_csv_data = csv_data.resample('M').sum()

ax = monthly_csv_data.plot(kind='line', figsize=(15, 3))
ax.set_title('Monthly Precipitation (variance= %.4f)' % (monthly_csv_data.var()))
# Out:
# Text(0.5, 1.0, 'Monthly Precipitation (variance= 2.2656)')

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

daily = pd.read_csv('../../../sample_dataset2.csv', header='infer')
daily.index = pd.to_datetime(daily['DATE'])
daily = daily['PRCP']

annual_data = daily.groupby(pd.Grouper(freq='Y')).sum()
ax = annual_data.plot(kind='line', figsize=(15, 3))
ax.set_title('Annual Precipitation (variance= %.4f)' % (annual_data.var()))

# %%
import pandas as pd

csv_data = pd.read_csv('../../../breast-cancer.txt', header='infer')

csv_data.columns = ['Sample code', 'Clump Thickness', 'Uniformity of Cell Size', 'Uniformity of Cell Shape',
                    'Marginal Adhesion', 'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
                    'Normal Nucleoli', 'Mitoses', 'Class']

csv_data = csv_data.drop(['Sample code'], axis=1)

print('Number of instances = %d' % (csv_data.shape[0]))
print('Number of attributes = %d' % (csv_data.shape[1]))

csv_data.head()
# Out:
# Number of instances = 698
# Number of attributes = 10
#    Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                5                        4                         4
# 1                3                        1                         1
# 2                6                        8                         8
# 3                4                        1                         1
# 4                8                       10                        10
#
#    Marginal Adhesion  Single Epithelial Cell Size Bare Nuclei  \
# 0                  5                            7          10
# 1                  1                            2           2
# 2                  1                            3           4
# 3                  3                            2           1
# 4                  8                            7          10
#
#    Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                3                2        1      2
# ...

# %%
import pandas as pd
csv_data = pd.read_csv('../../../breast-cancer.txt', header='infer')

csv_data.columns = ['Sample code', 'Clump Thickness', 'Uniformity of Cell Size', 'Uniformity of Cell Shape',
                    'Marginal Adhesion', 'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
                    'Normal Nucleoli', 'Mitoses', 'Class']
csv_data.sample(frac=0.02, random_state=1)
# Out:
#      Sample code  Clump Thickness  Uniformity of Cell Size  \
# 691       714039                3                        1
# 417      1240337                5                        2
# 605       353098                4                        1
# 349       836433                5                        1
# 134      1181356                5                        1
# 502      1265899                4                        1
# 117      1173514                1                        1
# 527       807657                6                        1
# 684       534555                1                        1
# 411      1238633               10                       10
# 268       385103                1                        1
# 312       693702                1                        1
# 375       640712                1                        1
# 23       1059552                1                        1
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


for column in csv_data.columns:
    
    csv_data[column].hist(bins=10)
    plt.title(f'Histogram of {column}')
    plt.ylabel('Frequency')
    plt.xlabel(column)
    
    plt.show()
    print(csv_data[column].value_counts(sort=False))
# Out:
# Clump Thickness
# 5     129
# 3     108
# 6      34
# 4      80
# 8      46
# 1     145
# 2      50
# 7      23
# 10     69
# 9      14
# Name: count, dtype: int64
# Uniformity of Cell Size
# 4      40
# 1     383
# 8      29
# 10     67
# 2      45
# 3      52
# 7      19
# 5      30
# 6      27
# 9       6
# Name: count, dtype: int64
# Uniformity of Cell Shape
# 4      44
# 1     352
# 8      28
# 10     58
# 2      59
# 3      56
# 5      34
# 6      30
# 7      30
# 9       7
# Name: count, dtype: int64
# Marginal Adhesion
# 5      23
# 1     406
# 3      58
# 8      25
# 10     55
# 4      33
# 6      22
# 2      58
# 9       5
# 7      13
# Name: count, dtype: int64
# Single Epithelial Cell Size
# 7      12
# 2     385
# 3      72
# 1      47
# 6      41
# 4      48
# 5      39
# 8      21
# 10     31
# 9       2
# Name: count, dtype: int64
# Bare Nuclei
# 10    132
# 2      30
# 4      19
# 1     401
# 3      28
# 9       9
# 7       8
# ?      16
# 5      30
# 8      21
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
#iris = pd.read_csv('../../../iris.txt', header='infer')

iris=load_iris()
x,y=iris.data,iris.target
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,test_size=0.5, random_state=123)
print(y_test)
print(y_train)
# Out:
# [1 2 2 1 0 2 1 0 0 1 2 0 1 2 2 2 0 0 1 0 0 2 0 2 0 0 0 2 2 0 2 2 0 0 1 1 2
#  0 0 1 1 0 2 2 2 2 2 1 0 0 2 0 0 1 1 1 1 2 1 2 0 2 1 0 0 2 1 2 2 0 1 1 2 0
#  2]
# [1 1 0 2 2 0 0 1 1 2 0 0 1 0 1 2 0 2 0 0 1 0 0 1 2 1 1 1 0 0 1 2 0 0 1 1 1
#  2 1 1 1 2 0 0 1 2 2 2 2 0 1 0 1 1 0 1 2 1 2 2 0 1 0 2 2 1 1 2 2 1 0 1 1 2
#  2]

# %%
pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/db/0d/1f6d2cd52c886707b00ddb7ed2504cbf10903a60a7bebcd71f0f77d53505/scikit_learn-1.3.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for scipy>=1.5.0 from https://files.pythonhosted.org/packages/50/8b/2057417a07a6fee8ed8be40e37bac4a502cae4cf44468a02962bbe81b8af/scipy-1.11.3-cp311-cp311-macosx_12_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.4/165.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

iris=load_iris()
x,y=iris.data,iris.target
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.9,test_size=0.1, random_state=123)
print(y_test)
print(y_train)
# Out:
# [1 2 2 1 0 2 1 0 0 1 2 0 1 2 2]
# [2 0 0 1 0 0 2 0 2 0 0 0 2 2 0 2 2 0 0 1 1 2 0 0 1 1 0 2 2 2 2 2 1 0 0 2 0
#  0 1 1 1 1 2 1 2 0 2 1 0 0 2 1 2 2 0 1 1 2 0 2 1 1 0 2 2 0 0 1 1 2 0 0 1 0
#  1 2 0 2 0 0 1 0 0 1 2 1 1 1 0 0 1 2 0 0 1 1 1 2 1 1 1 2 0 0 1 2 2 2 2 0 1
#  0 1 1 0 1 2 1 2 2 0 1 0 2 2 1 1 2 2 1 0 1 1 2 2]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


actual = [0,0,1,1,0,0,1,1,0,1]
predicted = [1,0,1,1,0,0,0,0,0,0] 

matrix = confusion_matrix(actual,predicted,labels=[1,0]) 
print('Confusion matrix: \n',matrix)

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1) 
print('Outcome values: \n', tp, fn, fp, tn)
# Out:
# Confusion matrix:
#  [[2 3]
#  [1 4]]
# Outcome values:
#  2 3 1 4
